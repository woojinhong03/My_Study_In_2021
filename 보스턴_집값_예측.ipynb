# %% [markdown]
# <a href="https://colab.research.google.com/github/woojinhong03/My_Study_In_2021/blob/main/%EB%B3%B4%EC%8A%A4%ED%84%B4_%EC%A7%91%EA%B0%92_%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
#과거의 데이터 준비
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
보스턴 = pd.read_csv(파일경로)
print(보스턴.columns)
보스턴.head()
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')
#       crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  medv
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
#독립, 종속 분리
독립 = 보스턴[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'b', 'lstat']]
종속 = 보스턴[['medv']]
print(독립.shape,종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
#모델 구조
X = tf.keras.layers.Input(shape=[13])
Y = tf.keras.layers.Dense(1)(X)
model = tf.keras.models.Model(X,Y)
model.compile(loss='mse')

# %%
#모델 학습
model.fit(독립, 종속, epochs=10000)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 7501/10000
# 16/16 [==============================] - 0s 2ms/step - loss: 24.0246
# Epoch 7502/10000
# 16/16 [==============================] - 0s 2ms/step - loss: 23.7042
# Epoch 7503/10000
# 16/16 [==============================] - 0s 2ms/step - loss: 23.7171
# Epoch 7504/10000
# 16/16 [==============================] - 0s 2ms/step - loss: 24.1422
# Epoch 7505/10000
# 16/16 [==============================] - 0s 2ms/step - loss: 23.7053
# Epoch 7506/10000
# 16/16 [==============================] - 0s 2ms/step - loss: 23.8582
# Epoch 7507/10000
# 16/16 [==============================] - 0s 3ms/step - loss: 23.9071
# Epoch 7508/10000
# 16/16 [==============================] - 0s 2ms/step - loss: 23.8258
# Epoch 7509/10000
# 16/16 [==============================] - 0s 2ms/step - loss: 23.5659
# Epoch 7510/10000
# 16/16 [==============================] - 0s 2ms/step - loss: 24.1282
# Epoch 7511/10000
# ...

# %%
#이용
model.predict(독립[0:5])
# Out:
# array([[29.471634],
#        [24.306543],
#        [30.884907],
#        [29.575111],
#        [29.192377]], dtype=float32)

# %%
종속[0:5]
# Out:
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
#모델의 수식 확인
model.get_weights()
# Out:
# [array([[-0.0976041 ],
#         [ 0.0466451 ],
#         [-0.0266421 ],
#         [ 2.6559956 ],
#         [-0.8578357 ],
#         [ 5.3197947 ],
#         [-0.01197992],
#         [-1.0357691 ],
#         [ 0.19447495],
#         [-0.01113754],
#         [-0.49686882],
#         [ 0.01347008],
#         [-0.46098277]], dtype=float32), array([6.8491826], dtype=float32)]
